# %%
#what is thread
#what is multithreading

# %%
import multiprocessing
import time
import os
import threading

starting_time = time.time()


def india():
    for i in range(1,11):
        time.sleep(0.5)
        print(f'India : {i}')

def canada():
    for i in range(1,11):
        time.sleep(0.5)
        print(f'canada : {i}')

def uk():
    for i in range(1,11):
        time.sleep(0.5)
        print(f'uk : {i}')

def usa():
    for j in range(1,11):
        time.sleep(0.5)
        print(f'USA : {j}')

def common():
    t1 = threading.Thread(target=india,args=())
    t2 = threading.Thread(target=canada,args=())

    t1.start()
    t2.start()

def common2():
    t3 = threading.Thread(target=usa,args=())
    t4 = threading.Thread(target=uk,args=())

    t3.start()
    t4.start()

if __name__ == "__main__":

    print(f'Main Processor Id : {os.getpid()}')
    cpu1 = multiprocessing.Process(target=common,args=())
    cpu2 = multiprocessing.Process(target=common2,args=())

    cpu1.start()
    cpu2.start()

    cpu1.join()
    cpu2.join()

    print(f'Main processor Exit')
    print(f'Total time : {time.time() - starting_time}')
# Out:
# Main Processor Id : 864
# India : 1canada : 1
#
# uk : 1USA : 1
#
# India : 2canada : 2
#
# USA : 2uk : 2
#
# canada : 3India : 3
#
# USA : 3uk : 3
#
# India : 4canada : 4
#
# USA : 4
# uk : 4
# India : 5
# canada : 5
# USA : 5
# uk : 5
# India : 6
# canada : 6
# USA : 6
# uk : 6
# India : 7
# canada : 7
# USA : 7
# uk : 7
# India : 8
# canada : 8USA : 8
#
# uk : 8
# India : 9
# canada : 9
# USA : 9uk : 9
#
# India : 10
# canada : 10
# USA : 10uk : 10
#
# Main processor Exit
# Total time : 5.118513345718384
